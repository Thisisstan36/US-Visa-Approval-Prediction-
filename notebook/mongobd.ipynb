# %%
print('ok')
# Out:
# ok

# %%
mongodb+srv://jayeshnikam4:<jayeshnikam4>@cluster0.0exctxs.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0

# %%
import pandas as pd

# %%
df = pd.read_csv('Visadataset.csv')
df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
data = df.to_dict(orient='records')
data
# Out:
# [{'case_id': 'EZYV01',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 14513,
#   'yr_of_estab': 2007,
#   'region_of_employment': 'West',
#   'prevailing_wage': 592.2029,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV02',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2412,
#   'yr_of_estab': 2002,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 83425.65,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV03',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'Y',
#   'no_of_employees': 44444,
#   'yr_of_estab': 2008,
#   'region_of_employment': 'West',
# ...

# %%
DB_NAME = 'US_VISA'
COLLECTION_NAME = 'visa_data'
CONNECTION_URL  = "mongodb+srv://jayeshnikam4:jayeshnikam4@cluster0.0exctxs.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# %%
import pymongo

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]
collection.insert_many(data)
# Out:
# InsertManyResult([ObjectId('662d38db6deec2ece9a01ea8'), ObjectId('662d38db6deec2ece9a01ea9'), ObjectId('662d38db6deec2ece9a01eaa'), ObjectId('662d38db6deec2ece9a01eab'), ObjectId('662d38db6deec2ece9a01eac'), ObjectId('662d38db6deec2ece9a01ead'), ObjectId('662d38db6deec2ece9a01eae'), ObjectId('662d38db6deec2ece9a01eaf'), ObjectId('662d38db6deec2ece9a01eb0'), ObjectId('662d38db6deec2ece9a01eb1'), ObjectId('662d38db6deec2ece9a01eb2'), ObjectId('662d38db6deec2ece9a01eb3'), ObjectId('662d38db6deec2ece9a01eb4'), ObjectId('662d38db6deec2ece9a01eb5'), ObjectId('662d38db6deec2ece9a01eb6'), ObjectId('662d38db6deec2ece9a01eb7'), ObjectId('662d38db6deec2ece9a01eb8'), ObjectId('662d38db6deec2ece9a01eb9'), ObjectId('662d38db6deec2ece9a01eba'), ObjectId('662d38db6deec2ece9a01ebb'), ObjectId('662d38db6deec2ece9a01ebc'), ObjectId('662d38db6deec2ece9a01ebd'), ObjectId('662d38db6deec2ece9a01ebe'), ObjectId('662d38db6deec2ece9a01ebf'), ObjectId('662d38db6deec2ece9a01ec0'), ObjectId('662d38db6deec2ece9a0
# ...

# %%
from from_root import from_root

# %%
export MONGODB_URL='mongodb+srv://jayeshnikam4:jayeshnikam4@cluster0.0exctxs.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'
